# %%
# test windy_grid_world
import gym
from gym import Env
from gridworld import WindyGridWorld
from core import Agent
from utils import learning_curve

# %%
env = WindyGridWorld()
env.reset()
env.render()
# Out:
# True

# %%
agent = Agent(env, capacity = 10000)
data = agent.learning(max_episode_num = 180, display = False)
# Out:
# 100%|██████████| 180/180 [00:26<00:00,  6.91it/s]

# %%
learning_curve(data, 2, 0, title = "learning curve", x_name = "episode", y_name="time steps")
# Out:
# No handles with labels found to put in legend.

# %%
agent = Agent(env, capacity = 10000)
data = agent.learning(max_episode_num = 2, display = True)
# Out:
#  50%|█████     | 1/2 [00:21<00:21, 21.05s/it]
# episode 0    4177 steps,total reward:-4176.00
# 100%|██████████| 2/2 [00:52<00:00, 26.25s/it]
# episode 1    6620 steps,total reward:-6619.00

# %%
env.close()
