# %% [markdown]
# # 21点游戏的蒙特卡洛学习策略迭代

# %% [markdown]
# ## 蒙特卡罗控制

# %%
from blackjack import Player, Dealer, Arena
# Player和Dealer都是一些简单的确定策略
# Dealer是超过17停止叫牌，否则继续叫牌
# Player是超过20停止叫牌，否则继续叫牌
from utils import str_key, set_dict, get_dict
from utils import draw_value, draw_policy
from utils import epsilon_greedy_policy
import math

# %%
class MC_Player(Player):
    '''具备蒙特卡罗控制能力的玩家
    '''
    def __init__(self, name = "", A = None, display = False):
        super(MC_Player, self).__init__(name, A, display)
        self.Q = {}   # 某一状态行为对的价值，策略迭代时使用
        self.Nsa = {} # Nsa的计数：某一状态行为对出现的次数
        self.total_learning_times = 0
        self.policy = self.epsilon_greedy_policy # 
        self.learning_method = self.learn_Q # 有了自己的学习方法
    
    def learn_Q(self, episode, r): # 从状态序列来学习Q值
        '''从一个Episode学习
        '''
        #for episode, r in episodes:
        for s, a in episode:
            nsa = get_dict(self.Nsa, s, a)
            set_dict(self.Nsa, nsa+1, s, a)
            q = get_dict(self.Q, s,a)
            set_dict(self.Q, q+(r-q)/(nsa+1), s, a)
        self.total_learning_times += 1
    
    def reset_memory(self):
        '''忘记既往学习经历
        '''
        self.Q.clear()
        self.Nsa.clear()
        self.total_learning_times = 0

    
    def epsilon_greedy_policy(self, dealer, epsilon = None):
        '''这里的贪婪策略是带有epsilon参数的
        '''
        player_points, _ = self.get_points()
        if player_points >= 21:
            return self.A[1]
        if player_points < 12:
            return self.A[0]
        else:
            A, Q = self.A, self.Q
            s = self.get_state_name(dealer)
            if epsilon is None:
                #epsilon = 1.0/(self.total_learning_times+1)
                #epsilon = 1.0/(1 + math.sqrt(1 + player.total_learning_times))
                epsilon = 1.0/(1 + 4 * math.log10(1+player.total_learning_times))
            return epsilon_greedy_policy(A, s, Q, epsilon)

# %%
A=["继续叫牌","停止叫牌"]
display = False
player = MC_Player(A = A, display = display)
dealer = Dealer(A = A, display = display)
# 创建一个场景
arena = Arena(A = A, display=display)

# %%
arena.play_games(dealer = dealer, player = player,num = 200000, show_statistic = True)
# Out:
# 100%|██████████| 200000/200000 [00:34<00:00, 5770.42it/s]
# 共玩了200000局，玩家赢84285局，和16674局，输99041局，胜率：0.42,不输率:0.50

# %%
draw_value(player.Q, useable_ace = True, is_q_dict=True, A = player.A)
draw_policy(epsilon_greedy_policy, player.A, player.Q, epsilon = 1e-10, useable_ace = True)
draw_value(player.Q, useable_ace = False, is_q_dict=True, A = player.A)
draw_policy(epsilon_greedy_policy, player.A, player.Q, epsilon = 1e-10, useable_ace = False)

# %%
display = False
arena.display = display
player.display = display
dealer.display = display
arena.play_games(dealer,player,num=10000, show_statistic = True)
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 5659.82it/s]
# 共玩了10000局，玩家赢4247局，和893局，输4860局，胜率：0.42,不输率:0.51

# %%
display = True
arena.display = display
player.display = display
dealer.display = display
arena.play_games(dealer,player,num=10, show_statistic = True)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 487.77it/s]
# ========= 开始新一局 =========
# 发了2张牌(['6', '2'])给玩家;玩家现在的牌:['6', '2']
# 发了2张牌(['9', '10'])给庄家;庄家现在的牌:['9', '10']
# 玩家选择:继续叫牌;发了1张牌(['7'])给玩家;玩家现在的牌:['6', '2', '7']
# 玩家选择:继续叫牌;发了1张牌(['K'])给玩家;玩家现在的牌:['6', '2', '7', 'K']
# 玩家选择:停止叫牌;玩家爆点25输了，得分:-1
# ========= 本局结束 ==========
# ========= 开始新一局 =========
# 发了2张牌(['8', 'A'])给玩家;玩家现在的牌:['8', 'A']
# 发了2张牌(['A', '8'])给庄家;庄家现在的牌:['A', '8']
# 玩家选择:停止叫牌;
# 庄家选择:停止叫牌;
# 双方均了停止叫牌;
# 玩家现在的牌:['8', 'A']
# 庄家现在的牌:['A', '8']
# 双方和局!玩家19点,庄家19点
# ========= 本局结束 ==========
# ========= 开始新一局 =========
# 发了2张牌(['2', '5'])给玩家;玩家现在的牌:['2', '5']
# 发了2张牌(['9', '3'])给庄家;庄家现在的牌:['9', '3']
# 玩家选择:继续叫牌;发了1张牌(['J'])给玩家;玩家现在的牌:['2', '5', 'J']
# 玩家选择:停止叫牌;
# 庄家选择:继续叫牌;发了1张牌(['K'])给庄家;庄家现在的牌:['9', '3', 'K']
# 庄家选择:停止叫牌;
# 双方均了停止叫牌;
# 玩家现在的牌:['2', '5', 'J']
# 庄家现在的牌:['9', '3', 'K']
# 玩家赢了!玩家17点,庄家22点
# ========= 本局结束 ==========
# ========= 开始新一局 =========
# 发了2张牌(['Q', '6'])给玩家;玩家现在的牌:['Q', '6']
# 发了2张牌(['3', '7'])给庄家;庄家现在的牌:['3', '7']
# 玩家选择:停止叫牌;
# 庄家选择:继续叫牌;发了1张牌(['8'])给庄家;庄家现在的牌:['3', '7', '8']
# 庄家选择:停止叫牌;
# 双方均了停止叫牌;
# 玩家现在的牌:['Q', '6']
# 庄家现在的牌:['3', '7', '8']
# 玩家输了!玩家16点,庄家18点
# ========= 本局结束 ==========
# ========= 开始新一局 =========
# 发了2张牌(['6', 'A'])给玩家;玩家现在的牌:['6', 'A']
# 发了2张牌(['7', 'J'])给庄家;庄家现在的牌:['7', 'J']
# 玩家选择:继续叫牌;发了1张牌(['8'])给玩家;玩家现在的牌:['6', 'A', '8']
# 玩家选择:继续叫牌;发了1张牌(['K'])给玩家;玩家现在的牌:['6', 'A', '8', 'K']
# 玩家选择:停止叫牌;玩家爆点25输了，得分:-1
# ========= 本局结束 ==========
# ========= 开始新一局 =========
#
# 发牌器没牌了，整理废牌，重新洗牌;一共整理了51张已用牌，重新放入发牌器
# 发了2张牌(['9', '7'])给玩家;玩家现在的牌:['9', '7']
# 发了2张牌(['5', '3'])给庄家;庄家现在的牌:['5', '3']
# 玩家选择:停止叫牌;
# 庄家选择:继续叫牌;发了1张牌(['8'])给庄家;庄家现在的牌:['5', '3', '8']
# 庄家选择:继续叫牌;发了1张牌(['4'])给庄家;庄家现在的牌:['5', '3', '8', '4']
# 庄家选择:停止叫牌;
# 双方均了停止叫牌;
# 玩家现在的牌:['9', '7']
# 庄家现在的牌:['5', '3', '8', '4']
# 玩家输了!玩家16点,庄家20点
# ========= 本局结束 ==========
# ========= 开始新一局 =========
# 发了2张牌(['Q', 'A'])给玩家;玩家现在的牌:['Q', 'A']
# 发了2张牌(['9', 'J'])给庄家;庄家现在的牌:['9', 'J']
# 玩家选择:停止叫牌;
# 庄家选择:停止叫牌;
# 双方均了停止叫牌;
# 玩家现在的牌:['Q', 'A']
# 庄家现在的牌:['9', 'J']
# 玩家赢了!玩家21点,庄家19点
# ========= 本局结束 ==========
# ========= 开始新一局 =========
# 发了2张牌(['3', '6'])给玩家;玩家现在的牌:['3', '6']
# 发了2张牌(['J', '2'])给庄家;庄家现在的牌:['J', '2']
# 玩家选择:继续叫牌;发了1张牌(['K'])给玩家;玩家现在的牌:['3', '6', 'K']
# 玩家选择:停止叫牌;
# 庄家选择:继续叫牌;发了1张牌(['10'])给庄家;庄家现在的牌:['J', '2', '10']
# 庄家选择:停止叫牌;
# 双方均了停止叫牌;
# 玩家现在的牌:['3', '6', 'K']
# 庄家现在的牌:['J', '2', '10']
# 玩家赢了!玩家19点,庄家22点
# ========= 本局结束 ==========
# ========= 开始新一局 =========
# 发了2张牌(['8', '8'])给玩家;玩家现在的牌:['8', '8']
# 发了2张牌(['5', '7'])给庄家;庄家现在的牌:['5', '7']
# 玩家选择:停止叫牌;
# 庄家选择:继续叫牌;发了1张牌(['2'])给庄家;庄家现在的牌:['5', '7', '2']
# 庄家选择:继续叫牌;发了1张牌(['A'])给庄家;庄家现在的牌:['5', '7', '2', 'A']
# 庄家选择:继续叫牌;发了1张牌(['Q'])给庄家;庄家现在的牌:['5', '7', '2', 'A', 'Q']
# 庄家选择:停止叫牌;
# 双方均了停止叫牌;
# 玩家现在的牌:['8', '8']
# 庄家现在的牌:['5', '7', '2', 'A', 'Q']
# 玩家赢了!玩家16点,庄家25点
# ========= 本局结束 ==========
# ========= 开始新一局 =========
# 发了2张牌(['6', '6'])给玩家;玩家现在的牌:['6', '6']
# 发了2张牌(['J', '4'])给庄家;庄家现在的牌:['J', '4']
# 玩家选择:继续叫牌;发了1张牌(['10'])给玩家;玩家现在的牌:['6', '6', '10']
# 玩家选择:停止叫牌;玩家爆点22输了，得分:-1
# ========= 本局结束 ==========
# 共玩了10局，玩家赢4局，和1局，输5局，胜率：0.40,不输率:0.50
